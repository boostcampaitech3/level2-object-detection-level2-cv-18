# %%
# 모듈 import

import wandb
from mmcv import Config
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector
from mmdet.datasets import (build_dataloader, build_dataset,
                            replace_ImageToTensor)

# %%
classes = ("General trash", "Paper", "Paper pack", "Metal", "Glass", 
           "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing")

# config file 들고오기
cfg = Config.fromfile('./cascade_swinT_fpncarafe_4Conv1FcHead.py')

root='../../dataset/'

# dataset config 수정
cfg.data.train.img_prefix = root
# cfg.data.train.pipeline[2]['img_scale'] = (512,512) # Resize

cfg.data.test.img_prefix = root
# cfg.data.test.pipeline[1]['img_scale'] = (512,512) # Resize

cfg.data.samples_per_gpu = 4 #batch size

cfg.seed = 2021
cfg.gpu_ids = [0]
cfg.work_dir = './work_dirs/aug_set2_fpncarafe_4Conv1FcHead'


cfg.optimizer_config.grad_clip = dict(max_norm=35, norm_type=2)
cfg.checkpoint_config = dict(max_keep_ckpts=10, interval=1)

# %%
# build_dataset
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.29s)
# creating index...
# index created!
# /opt/conda/envs/detection/lib/python3.7/site-packages/albumentations/augmentations/transforms.py:1953: UserWarning: blur_limit and sigma_limit minimum value can not be both equal to 0. blur_limit minimum value changed to 3.
#   "blur_limit and sigma_limit minimum value can not be both equal to 0. "
# /opt/conda/envs/detection/lib/python3.7/site-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,

# %%
# dataset 확인
datasets[0]
# Out:
# CocoDataset Train dataset with number of images 9649, and instance counts:
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+
# | category          | count | category      | count | category        | count | category    | count | category     | count |
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+
# | 0 [General trash] | 9418  | 1 [Paper]     | 6004  | 2 [Paper pack]  | 1573  | 3 [Metal]   | 1459  | 4 [Glass]    | 1625  |
# | 5 [Plastic]       | 4481  | 6 [Styrofoam] | 2187  | 7 [Plastic bag] | 7461  | 8 [Battery] | 1652  | 9 [Clothing] | 1480  |
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+

# %%
# 모델 build 및 pretrained network 불러오기
model = build_detector(cfg.model)
model.init_weights()
# Out:
# 2022-04-04 20:26:51,407 - mmdet - INFO - load checkpoint from http path: https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth
# 2022-04-04 20:26:51,645 - mmdet - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2022-04-04 20:26:51,654 - mmdet - INFO - initialize Shared4Conv1FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2022-04-04 20:26:51,750 - mmdet - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# ...

# %%
# 모델 학습
train_detector(model, datasets[0], cfg, distributed=False, validate=True)
# Out:
# 2022-04-04 20:26:56,882 - mmdet - INFO - Start running, host: root@3c89da8245a6, work_dir: /opt/ml/level2-object-detection-level2-cv-18/Mmdetection/_MyModel/work_dirs/cascade_swinT_fpncarafe_4Conv1FcHead2
# 2022-04-04 20:26:56,883 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) CosineRestartLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) CosineRestartLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) CosineRestartLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# ...
