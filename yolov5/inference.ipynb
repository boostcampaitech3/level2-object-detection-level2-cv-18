# %%
import torch
import pandas as pd 
from PIL import Image
from tqdm import tqdm

model = torch.hub.load('./utils','custom',path='/opt/ml/yolov5/runs/train/exp6/weights/best.pt',source='local')
model.conf = 0.001
model.iou = 0.5
img_path = '/opt/ml/detection/dataset/'

prediction_string = [''for i in range(4871)]
image_id = [f'test/{i:04}.jpg' for i in range(4871)]

for i in tqdm(range(len(image_id))):
    img = Image.open(img_path+image_id[i])
    preds = model(img,size=1024,augment=True)
    for data in preds.pandas().xyxy[0].values:
        x1,y1,x2,y2,conf,cls,label = data
        prediction_string[i] += f'{cls} {conf} {x1} {y1} {x2} {y2} '
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_32102/3681265060.py in <module>
#       4 from tqdm import tqdm
#       5
# ----> 6 model = torch.hub.load('./utils','custom',path='/opt/ml/yolov5/runs/train/exp6/weights/best.pt',source='local')
#       7 model.conf = 0.001
#       8 model.iou = 0.5
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/torch/hub.py in load(repo_or_dir, model, source, force_reload, verbose, skip_validation, *args, **kwargs)
#     402         repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, verbose, skip_validation)
#     403
# --> 404     model = _load_local(repo_or_dir, model, *args, **kwargs)
#     405     return model
#     406
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/torch/hub.py in _load_local(hubconf_dir, model, *args, **kwargs)
#     428
#     429     hubconf_path = os.path.join(hubconf_dir, MODULE_HUBCONF)
# --> 430     hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
#     431
#     432     entry = _load_entry_from_hubconf(hub_module, model)
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/torch/hub.py in _import_module(name, path)
#      74     module = importlib.util.module_from_spec(spec)
#      75     assert isinstance(spec.loader, Loader)
# ---> 76     spec.loader.exec_module(module)
#      77     return module
#      78
#
# /opt/conda/envs/detection/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /opt/conda/envs/detection/lib/python3.7/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /opt/conda/envs/detection/lib/python3.7/importlib/_bootstrap_external.py in get_data(self, path)
#
# FileNotFoundError: [Errno 2] No such file or directory: './utils/hubconf.py'

# %%
submission = pd.DataFrame()
submission['PredictionString'] = prediction_string
submission['image_id'] = image_id
submission.to_csv("./submission.csv", index=False)

# %%
print(prediction_string[0])
# Out:
# 7 0.9740670919418335 601.3475341796875 517.0161743164062 957.47509765625 1023.0358276367188 7 0.9708001613616943 218.10569763183594 50.56440734863281 455.325927734375 472.20782470703125 7 0.967248260974884 448.051513671875 600.0189208984375 647.199951171875 876.356689453125 7 0.9600250720977783 390.340576171875 190.02627563476562 602.2156982421875 545.732177734375 7 0.9504562020301819 653.7874755859375 337.8564758300781 877.401611328125 606.76953125 7 0.9464901685714722 117.45832824707031 417.2423095703125 331.96356201171875 715.2259521484375 1 0.9240362644195557 566.87890625 105.48980712890625 740.8214111328125 360.69482421875 5 0.9217198491096497 342.180908203125 642.5205688476562 394.6527099609375 725.9894409179688 7 0.9001790881156921 552.694091796875 341.90423583984375 702.53662109375 601.9331665039062 7 0.8943935632705688 242.91580200195312 408.0710754